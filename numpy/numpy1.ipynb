# %%
import numpy as py

# %% [markdown]
# ### Array created

# %%
a = py.array([1,2,3,4,5])
print(a)
# Out:
# [1 2 3 4 5]

# %% [markdown]
# ### Array by arange

# %%
arr_table = py.arange(10000) * 2
print(arr_table)
# Out:
# [    0     2     4 ... 19994 19996 19998]

# %%
arr_zero = py.zeros(3)
print(arr_zero)

arr_ones = py.ones(3)
print(arr_ones)
# Out:
# [0. 0. 0.]
# [1. 1. 1.]

# %%
arr = py.array([[1,2,3,4] , [5,6,7,8]])

print(arr.size)
print(arr.shape)
# Out:
# 8
# (2, 4)

# %% [markdown]
# ## Transpose of matrices

# %%
arr1 = py.array([[1,2,3] , [4,5,6]])
print(arr1.flatten())
print(arr1.T)
# Out:
# [1 2 3 4 5 6]
# [[1 4]
#  [2 5]
#  [3 6]]
